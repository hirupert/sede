# %%
import os
import pandas as pd

# %% [markdown]
# Read annotated CSV file

# %%
annotated_df = pd.read_csv('../data/DataExp4_filtered_test_val_annotated.csv')
original_annotated_df = pd.read_csv('../data/DataExp4_filtered_test_val_annotated.csv')

# %%
not_annotated_df = pd.read_csv('../data/DataExp4_filtered_not_annotated.csv')

# %%
if "Unnamed: 0" in annotated_df.columns:
    annotated_df.drop(["Unnamed: 0"], axis=1, inplace=True)
if "Unnamed: 0" in original_annotated_df.columns:
    original_annotated_df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
if "Unnamed: 0" in not_annotated_df.columns:
    not_annotated_df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %% [markdown]
# Fill the fixed title and fixed query body with the fixed ones, if available

# %%
annotated_df["Fixed Title"].fillna(annotated_df["Title"], inplace=True)
annotated_df["Fixed QueryBody"].fillna(annotated_df["QueryBody"], inplace=True)

# %%
not_annotated_df["Fixed Title"].fillna(not_annotated_df["Title"], inplace=True)
not_annotated_df["Fixed QueryBody"].fillna(not_annotated_df["QueryBody"], inplace=True)

# %%
annotated_df["Type of Fix"].fillna("", inplace=True)
annotated_df["Type of Fix"].unique()
# Out:
# array(['C', 'T', 'IC', 'NINC', 'NIC', 'INC', 'NEC', 'c', 't'],
#       dtype=object)

# %%
original_annotated_df["Type of Fix"].fillna("", inplace=True)
original_annotated_df["Type of Fix"].unique()
# Out:
# array(['C', 'T', 'IC', 'NINC', 'NIC', 'INC', 'NEC', 'c', 't'],
#       dtype=object)

# %%
annotated_df["Type of Fix"] = annotated_df["Type of Fix"].apply(lambda x: x.upper())

# %%
original_annotated_df["Type of Fix"] = original_annotated_df["Type of Fix"].apply(lambda x: x.upper())

# %% [markdown]
# Remove rows without annotation or rows that couldn't be fixed

# %%
filtered_annotated_df = annotated_df[~annotated_df["Type of Fix"].isin({"NIC", "NINC", "NEC", "INC"})].copy()

# %%
filtered_annotated_df
# Out:
#       QuerySetId                                              Title  \
# 0           1233                         Top 500 Askers on the site
# 1           1308                  Average rep gain per post per tag
# 2           1704                    Up vs Down votes by hour of day
# 3           2304              Posts containing tr.im shortened URLs
# 4           3055       Users with 10+ Accounts Including Reputation
# ...          ...                                                ...
# 2005     1340757       Time to first answer (self-answers excluded)
# 2008     1344248                             Number of Posts by Tag
# 2009     1344640    Tags ordered by average question score (non CW)
# 2010     1344742                Recent suggested edits on tag-infos
# 2011     1344748  Recent suggested edits on tag-infos (only pend...
#
#                                             Description  \
# 0     A list of the top 500 askers of questions\nord...
# 1                                                   NaN
# 2     Doesn't currently work, but that's just becaus...
# 3     Posts containing tr.im shortened URLs, which w...
# 4     A copy of http://odata.stackexchange.com/stack...
# ...                                                 ...
# 2005                                                NaN
# 2008                                                NaN
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
#
#                                               QueryBody         CreationDate  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...  2010-05-27 20:08:16
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...  2010-05-27 23:04:48
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...   2020-06-16 4:01:50
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...  2010-06-05 16:34:19
# 4     WITH  10+ Accounts Including Reputation\n-- A ...  2010-06-13 21:30:53
# ...                                                 ...                  ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...   2020-12-05 0:28:45
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...  2020-12-09 19:43:28
# 2009  SELECT  TOP(##num?100##)\n  RANK() OVER(ORDER ...   2020-12-10 4:10:13
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 11:56:11
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 14:42:00
#
#                                             Fixed Title  \
# 0                            Top 500 Askers on the site
# 1     Average rep gain per post per tag (more than 1...
# 2                       Up vs Down votes by hour of day
# 3                 Posts containing tr.im shortened URLs
# 4          Users with 10+ Accounts Including Reputation
# ...                                                 ...
# 2005  Time to first answer by minutes (self-answers ...
# 2008                             Number of Posts by Tag
# 2009    Tags ordered by average question score (non CW)
# 2010            Recent 250 suggested edits on tag-infos
# 2011  Recent 250 suggested edits on tag-infos (only ...
#
#                                         Fixed QueryBody Type of Fix   Fixer  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...           C  Vibhor
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...           T   Moshe
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...           C  Vibhor
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...           C   Moshe
# 4     SELECT\n    sum(u1.Reputation) AS TotalRep,\n ...          IC   Moshe
# ...                                                 ...         ...     ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...           T   Moshe
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...          IC   Moshe
# 2009  SELECT \n  RANK() OVER(ORDER BY AVG(CAST(q.SCO...          IC   Moshe
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...           T   Moshe
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...           T   Moshe
#
#       Faruk_Error
# 0             0.0
# 1             0.0
# 2             1.0
# 3             0.0
# 4             1.0
# ...           ...
# 2005          1.0
# 2008          0.0
# 2009          1.0
# 2010          1.0
# 2011          1.0
#
# [1714 rows x 10 columns]

# %%
original_annotated_df = original_annotated_df[~original_annotated_df["Type of Fix"].isin({"NIC", "NINC", "NEC", "INC"})].copy()

# %%
original_annotated_df
# Out:
#       QuerySetId                                              Title  \
# 0           1233                         Top 500 Askers on the site
# 1           1308                  Average rep gain per post per tag
# 2           1704                    Up vs Down votes by hour of day
# 3           2304              Posts containing tr.im shortened URLs
# 4           3055       Users with 10+ Accounts Including Reputation
# ...          ...                                                ...
# 2005     1340757       Time to first answer (self-answers excluded)
# 2008     1344248                             Number of Posts by Tag
# 2009     1344640    Tags ordered by average question score (non CW)
# 2010     1344742                Recent suggested edits on tag-infos
# 2011     1344748  Recent suggested edits on tag-infos (only pend...
#
#                                             Description  \
# 0     A list of the top 500 askers of questions\nord...
# 1                                                   NaN
# 2     Doesn't currently work, but that's just becaus...
# 3     Posts containing tr.im shortened URLs, which w...
# 4     A copy of http://odata.stackexchange.com/stack...
# ...                                                 ...
# 2005                                                NaN
# 2008                                                NaN
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
#
#                                               QueryBody         CreationDate  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...  2010-05-27 20:08:16
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...  2010-05-27 23:04:48
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...   2020-06-16 4:01:50
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...  2010-06-05 16:34:19
# 4     WITH  10+ Accounts Including Reputation\n-- A ...  2010-06-13 21:30:53
# ...                                                 ...                  ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...   2020-12-05 0:28:45
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...  2020-12-09 19:43:28
# 2009  SELECT  TOP(##num?100##)\n  RANK() OVER(ORDER ...   2020-12-10 4:10:13
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 11:56:11
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 14:42:00
#
#                                             Fixed Title  \
# 0                                                   NaN
# 1     Average rep gain per post per tag (more than 1...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2005  Time to first answer by minutes (self-answers ...
# 2008                                                NaN
# 2009                                                NaN
# 2010            Recent 250 suggested edits on tag-infos
# 2011  Recent 250 suggested edits on tag-infos (only ...
#
#                                         Fixed QueryBody Type of Fix   Fixer  \
# 0                                                   NaN           C  Vibhor
# 1                                                   NaN           T   Moshe
# 2                                                   NaN           C  Vibhor
# 3                                                   NaN           C   Moshe
# 4     SELECT\n    sum(u1.Reputation) AS TotalRep,\n ...          IC   Moshe
# ...                                                 ...         ...     ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...           T   Moshe
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...          IC   Moshe
# 2009  SELECT \n  RANK() OVER(ORDER BY AVG(CAST(q.SCO...          IC   Moshe
# 2010                                                NaN           T   Moshe
# 2011                                                NaN           T   Moshe
#
#       Faruk_Error
# 0             0.0
# 1             0.0
# 2             1.0
# 3             0.0
# 4             1.0
# ...           ...
# 2005          1.0
# 2008          0.0
# 2009          1.0
# 2010          1.0
# 2011          1.0
#
# [1714 rows x 10 columns]

# %%
filtered_annotated_df["validated"] = (filtered_annotated_df["Type of Fix"].fillna('') != '').astype(bool)

# %%
original_annotated_df["validated"] = (original_annotated_df["Type of Fix"].fillna('') != '').astype(bool)

# %% [markdown]
# Delete unused columns

# %%
del filtered_annotated_df["Title"]
del filtered_annotated_df["QueryBody"]
del filtered_annotated_df["Type of Fix"]
del filtered_annotated_df["Fixer"]
del filtered_annotated_df["Faruk_Error"]

# %%
del annotated_df["Title"]
del annotated_df["QueryBody"]
del annotated_df["Type of Fix"]
del annotated_df["Fixer"]
del annotated_df["Faruk_Error"]

# %%
del original_annotated_df["Fixed Title"]
del original_annotated_df["Fixed QueryBody"]
del original_annotated_df["Type of Fix"]
del original_annotated_df["Fixer"]
del original_annotated_df["Faruk_Error"]

# %%
del not_annotated_df["Title"]
del not_annotated_df["QueryBody"]
del not_annotated_df["Type of Fix"]
del not_annotated_df["Fixer"]
del not_annotated_df["Faruk_Error"]

# %% [markdown]
# Rename columns back again

# %%
filtered_annotated_df.rename(columns={"Fixed Title": "Title", "Fixed QueryBody": "QueryBody"}, inplace=True)
annotated_df.rename(columns={"Fixed Title": "Title", "Fixed QueryBody": "QueryBody"}, inplace=True)
not_annotated_df.rename(columns={"Fixed Title": "Title", "Fixed QueryBody": "QueryBody"}, inplace=True)

# %% [markdown]
# Reorder columns

# %%
cols = ["QuerySetId", "Title", "Description", "QueryBody", "CreationDate", "validated"]

# %%
filtered_annotated_df = filtered_annotated_df[cols]
original_annotated_df = original_annotated_df[cols]

# %%
not_annotated_df["validated"] = False
annotated_df["validated"] = False

# %%
annotated_df = annotated_df[cols]

# %%
not_annotated_df = not_annotated_df[cols]

# %% [markdown]
# Check final dataframe before saving it to disk

# %%
filtered_annotated_df
# Out:
#       QuerySetId                                              Title  \
# 0           1233                         Top 500 Askers on the site
# 1           1308  Average rep gain per post per tag (more than 1...
# 2           1704                    Up vs Down votes by hour of day
# 3           2304              Posts containing tr.im shortened URLs
# 4           3055       Users with 10+ Accounts Including Reputation
# ...          ...                                                ...
# 2005     1340757  Time to first answer by minutes (self-answers ...
# 2008     1344248                             Number of Posts by Tag
# 2009     1344640    Tags ordered by average question score (non CW)
# 2010     1344742            Recent 250 suggested edits on tag-infos
# 2011     1344748  Recent 250 suggested edits on tag-infos (only ...
#
#                                             Description  \
# 0     A list of the top 500 askers of questions\nord...
# 1                                                   NaN
# 2     Doesn't currently work, but that's just becaus...
# 3     Posts containing tr.im shortened URLs, which w...
# 4     A copy of http://odata.stackexchange.com/stack...
# ...                                                 ...
# 2005                                                NaN
# 2008                                                NaN
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
#
#                                               QueryBody         CreationDate  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...  2010-05-27 20:08:16
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...  2010-05-27 23:04:48
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...   2020-06-16 4:01:50
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...  2010-06-05 16:34:19
# 4     SELECT\n    sum(u1.Reputation) AS TotalRep,\n ...  2010-06-13 21:30:53
# ...                                                 ...                  ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...   2020-12-05 0:28:45
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...  2020-12-09 19:43:28
# 2009  SELECT \n  RANK() OVER(ORDER BY AVG(CAST(q.SCO...   2020-12-10 4:10:13
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 11:56:11
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 14:42:00
#
#       validated
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ...         ...
# 2005       True
# 2008       True
# 2009       True
# 2010       True
# 2011       True
#
# [1714 rows x 6 columns]

# %%
not_annotated_df
# Out:
#        QuerySetId                                              Title  \
# 0             466               Most controversial posts on the site
# 1             784      Comments asking for questions to be made wiki
# 2             785           How many upvotes do I have for each tag?
# 3             873                 Posts containing a very short body
# 4             877                Posts containing a very short title
# ...           ...                                                ...
# 10304     1344785                 Duplicate target of the given post
# 10305     1344986      My score and number of non-CW answers per tag
# 10306     1345529  select  p1.id from (select * from Posts where ...
# 10307     1346132                     Percentage of SO Users on Meta
# 10308     1346153         List of deleted posts which are duplicates
#
#                                              Description  \
# 0      Looks for posts with more than half the amount...
# 1      All comments that contain the text should and ...
# 2                    how long before I get tag badges?\n
# 3      Posts containing a body that is less than 8 ch...
# 4      Posts containing a body that is less than 5 ch...
# ...                                                  ...
# 10304                                                NaN
# 10305                                                NaN
# 10306                                                NaN
# 10307                                                NaN
# 10308                                                NaN
#
#                                                QueryBody         CreationDate  \
# 0                                  SELECT \n* from Votes  2020-06-24 11:23:10
# 1      SELECT  PostId as [Post Link], Text from Comme...  2019-07-07 11:01:51
# 2      DECLARE  @UserId int = ##UserId##\n\nSELECT --...  2020-12-06 01:47:00
# 3      SELECT  Id as [Post Link], Body, Score from Po...  2020-11-30 04:11:17
# 4      SELECT  Id as [Post Link], Body, Score from Po...  2020-11-25 01:19:00
# ...                                                  ...                  ...
# 10304  SELECT \n  RelatedPostId AS [Post Link]\nFROM ...  2020-12-10 13:45:57
# 10305  SELECT \n  t.TagName,\n  SUM(a.Score) AS [Tota...  2020-12-10 14:58:32
# 10306  SELECT   p1.id from (SELECT * from Posts where...  2020-12-10 17:32:25
# 10307                        SELECT  count(*) from users  2020-12-10 20:19:25
# 10308  SELECT  TOP(##num?1000##)\n  p.Id AS [Post lin...  2020-12-10 21:15:58
#
#        validated
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 10304      False
# 10305      False
# 10306      False
# 10307      False
# 10308      False
#
# [10309 rows x 6 columns]

# %%
annotated_df
# Out:
#       QuerySetId                                              Title  \
# 0           1233                         Top 500 Askers on the site
# 1           1308  Average rep gain per post per tag (more than 1...
# 2           1704                    Up vs Down votes by hour of day
# 3           2304              Posts containing tr.im shortened URLs
# 4           3055       Users with 10+ Accounts Including Reputation
# ...          ...                                                ...
# 2007     1344021  как подсчитать количество записей в таблице с ...
# 2008     1344248                             Number of Posts by Tag
# 2009     1344640    Tags ordered by average question score (non CW)
# 2010     1344742            Recent 250 suggested edits on tag-infos
# 2011     1344748  Recent 250 suggested edits on tag-infos (only ...
#
#                                             Description  \
# 0     A list of the top 500 askers of questions\nord...
# 1                                                   NaN
# 2     Doesn't currently work, but that's just becaus...
# 3     Posts containing tr.im shortened URLs, which w...
# 4     A copy of http://odata.stackexchange.com/stack...
# ...                                                 ...
# 2007                                                NaN
# 2008                                                NaN
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
#
#                                               QueryBody         CreationDate  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...  2010-05-27 20:08:16
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...  2010-05-27 23:04:48
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...   2020-06-16 4:01:50
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...  2010-06-05 16:34:19
# 4     SELECT\n    sum(u1.Reputation) AS TotalRep,\n ...  2010-06-13 21:30:53
# ...                                                 ...                  ...
# 2007  WITH  [data] as (select \n  users.id, \n  Year...  2020-12-09 12:24:07
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...  2020-12-09 19:43:28
# 2009  SELECT \n  RANK() OVER(ORDER BY AVG(CAST(q.SCO...   2020-12-10 4:10:13
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 11:56:11
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 14:42:00
#
#       validated
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 2007      False
# 2008      False
# 2009      False
# 2010      False
# 2011      False
#
# [2012 rows x 6 columns]

# %%
original_annotated_df
# Out:
#       QuerySetId                                              Title  \
# 0           1233                         Top 500 Askers on the site
# 1           1308                  Average rep gain per post per tag
# 2           1704                    Up vs Down votes by hour of day
# 3           2304              Posts containing tr.im shortened URLs
# 4           3055       Users with 10+ Accounts Including Reputation
# ...          ...                                                ...
# 2005     1340757       Time to first answer (self-answers excluded)
# 2008     1344248                             Number of Posts by Tag
# 2009     1344640    Tags ordered by average question score (non CW)
# 2010     1344742                Recent suggested edits on tag-infos
# 2011     1344748  Recent suggested edits on tag-infos (only pend...
#
#                                             Description  \
# 0     A list of the top 500 askers of questions\nord...
# 1                                                   NaN
# 2     Doesn't currently work, but that's just becaus...
# 3     Posts containing tr.im shortened URLs, which w...
# 4     A copy of http://odata.stackexchange.com/stack...
# ...                                                 ...
# 2005                                                NaN
# 2008                                                NaN
# 2009                                                NaN
# 2010                                                NaN
# 2011                                                NaN
#
#                                               QueryBody         CreationDate  \
# 0     SELECT  * FROM (\nSELECT \n    TOP 500\n    Ow...  2010-05-27 20:08:16
# 1     SELECT   t.tagName \n,       COUNT(*) as NrOfQ...  2010-05-27 23:04:48
# 2     SELECT \n    DATEPART(HOUR, p.CreationDate) AS...   2020-06-16 4:01:50
# 3     SELECT  Id as [Post Link], Body\nfrom Posts \n...  2010-06-05 16:34:19
# 4     WITH  10+ Accounts Including Reputation\n-- A ...  2010-06-13 21:30:53
# ...                                                 ...                  ...
# 2005  SELECT  DATEDIFF(MINUTE, q.CreationDate, a.Cre...   2020-12-05 0:28:45
# 2008  SELECT \n  TAG.id,\n  TAG.TagName,\n  count(*)...  2020-12-09 19:43:28
# 2009  SELECT  TOP(##num?100##)\n  RANK() OVER(ORDER ...   2020-12-10 4:10:13
# 2010  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 11:56:11
# 2011  SELECT  TOP(##num?250##)\n  s.Id AS [Suggested...  2020-12-10 14:42:00
#
#       validated
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ...         ...
# 2005       True
# 2008       True
# 2009       True
# 2010       True
# 2011       True
#
# [1714 rows x 6 columns]

# %%
filtered_annotated_df.to_csv("../data/DataExp4_filtered_fixed.csv", index=False)

# %% [markdown]
# Split into train/val/test sets

# %%
val_test_df = filtered_annotated_df[filtered_annotated_df["validated"]]
original_val_test_df = original_annotated_df[original_annotated_df["validated"]]

# %%
train_df = not_annotated_df.copy()

# %%
val_test_query_set_ids = val_test_df["QuerySetId"].tolist()
train_query_set_ids = train_df["QuerySetId"].tolist()
val_test_query_set_ids_in_train = [sql for sql in val_test_query_set_ids if sql in train_query_set_ids]
print(f"Number of QuerySetId in val/test that appear in train: {len(val_test_query_set_ids_in_train)}")
# Out:
# Number of QuerySetId in val/test that appear in train: 0

# %%
val_df = val_test_df.iloc[:int(val_test_df.shape[0] / 2)]
test_df = val_test_df.iloc[int(val_test_df.shape[0] / 2):]

# %%
original_val_df = original_val_test_df.iloc[:int(original_val_test_df.shape[0] / 2)]
original_test_df = original_val_test_df.iloc[int(original_val_test_df.shape[0] / 2):]

# %%
if not os.path.exists("../data/sede/"):
    os.makedirs("../data/sede/")

# %%
print(f"Train set size: {len(train_df)}")
print(f"Val set size: {len(val_df)}")
print(f"Test set size: {len(test_df)}")
print(f"Original Val set size: {len(original_val_df)}")
print(f"Original Test set size: {len(original_test_df)}")
# Out:
# Train set size: 10309
# Val set size: 857
# Test set size: 857
# Original Val set size: 857
# Original Test set size: 857

# %%
train_df.to_json("../data/sede/train.jsonl", orient="records", lines=True)
val_df.to_json("../data/sede/val.jsonl", orient="records", lines=True)
original_val_df.to_json("../data/sede/val_original.jsonl", orient="records", lines=True)
test_df.to_json("../data/sede/test.jsonl", orient="records", lines=True)
original_test_df.to_json("../data/sede/test_original.jsonl", orient="records", lines=True)
